# %%
import torch
from pathlib import Path
import os
os.chdir('../../SDv1.5')
from metrics_utils import VGGCalculator, CLIPScorer, calculate_aesthetic_score, DINOStyleScorer
from notebooks.prompts_dict import common_prompts as prompts

# %%
VGG_Scorer = VGGCalculator()
CLIP_Scorer = CLIPScorer()
#DINO_Scorer = DINOStyleScorer()

# %%
skip_steps = 10
CFG = 15
swap_guidance_scale = 15
sparse_weight = 0
interpolation=[0.1]

for int_value in interpolation:
  for j in [1,2,3,4,5]:
    clip_loss = 0
    vgg_loss = 0
    aesthetic_score = 0
    dino_loss = 0
    ref_image_path = f'neurips_demo/CFG{CFG}_sfg{swap_guidance_scale}_skip{skip_steps}/style{j}_{sparse_weight}_int_{int_value}'
    image_path_list = os.listdir(ref_image_path)
    for i, image_path in enumerate(image_path_list):
        tmp_dir = os.listdir(os.path.join(ref_image_path, prompts[i+1]))[0]
        full_image_path = os.path.join(ref_image_path, prompts[i+1],tmp_dir,'out_transfer---seed_42.png')
        style_image_path = os.path.join(ref_image_path, prompts[i+1],tmp_dir,'out_style---seed_42.png')

        clip_loss += CLIP_Scorer(full_image_path, 'a sketch of '+prompts[i+1])
        vgg_loss += VGG_Scorer.calculate_similarity(full_image_path, style_image_path)
        aesthetic_score+= calculate_aesthetic_score(full_image_path)
        #dino_loss += DINO_Scorer(full_image_path, style_image_path)
        
    print(f"Style {j} int {int_value}, CLIP loss: {clip_loss/len(image_path_list)}, VGG loss: {vgg_loss/len(image_path_list)}, \
          asesthetic_score: {aesthetic_score/len(image_path_list)}, dino_loss: {dino_loss/len(image_path_list)}")
  print('----------------------------------')
# Out:
# Style 1 int 0.1, CLIP loss: 0.3514404296875, VGG loss: 0.020237557590007782,           asesthetic_score: tensor([[4.9815]], device='cuda:0', grad_fn=<DivBackward0>), dino_loss: 0.0
# Style 2 int 0.1, CLIP loss: 0.345576171875, VGG loss: 0.06138656660914421,           asesthetic_score: tensor([[4.9136]], device='cuda:0', grad_fn=<DivBackward0>), dino_loss: 0.0
# Style 3 int 0.1, CLIP loss: 0.342939453125, VGG loss: 0.05534883961081505,           asesthetic_score: tensor([[4.9880]], device='cuda:0', grad_fn=<DivBackward0>), dino_loss: 0.0
# Style 4 int 0.1, CLIP loss: 0.352880859375, VGG loss: 0.0136506212875247,           asesthetic_score: tensor([[4.9429]], device='cuda:0', grad_fn=<DivBackward0>), dino_loss: 0.0
# Style 5 int 0.1, CLIP loss: 0.350185546875, VGG loss: 0.027066707611083984,           asesthetic_score: tensor([[5.0793]], device='cuda:0', grad_fn=<DivBackward0>), dino_loss: 0.0
# ----------------------------------

# %%
skip_steps = 10
CFG = 15
swap_guidance_scale = 25
sparse_weight = 60
interpolation=[0.05]

for int_value in interpolation:
  for j in [6]:
    clip_loss = 0
    vgg_loss = 0
    aesthetic_score = 0
    dino_loss = 0

    ref_image_path = f'neurips_demo/CFG{CFG}_sfg{swap_guidance_scale}_skip{skip_steps}/style{j}_{sparse_weight}_int_{int_value}'
    image_path_list = os.listdir(ref_image_path)
    for i, image_path in enumerate(image_path_list):
        tmp_dir = os.listdir(os.path.join(ref_image_path, prompts[i+1]))[0]
        full_image_path = os.path.join(ref_image_path, prompts[i+1],tmp_dir,'out_transfer---seed_42.png')
        style_image_path = os.path.join(ref_image_path, prompts[i+1],tmp_dir,'out_style---seed_42.png')

        clip_loss += CLIP_Scorer(full_image_path, 'a sketch of '+prompts[i+1])
        vgg_loss += VGG_Scorer.calculate_similarity(full_image_path, style_image_path)
        aesthetic_score+= calculate_aesthetic_score(full_image_path)
        #dino_loss += DINO_Scorer(full_image_path, style_image_path)
        
    print(f"Style {j} int {int_value}, CLIP loss: {clip_loss/len(image_path_list)}, VGG loss: {vgg_loss/len(image_path_list)}, \
          asesthetic_score: {aesthetic_score/len(image_path_list)},dino_loss: {dino_loss/len(image_path_list)}")
  print('----------------------------------')
# Out:
# Style 6 int 0.05, CLIP loss: 0.339248046875, VGG loss: 0.017309166491031647,           asesthetic_score: tensor([[4.1981]], device='cuda:0', grad_fn=<DivBackward0>),dino_loss: 0.0
# ----------------------------------
